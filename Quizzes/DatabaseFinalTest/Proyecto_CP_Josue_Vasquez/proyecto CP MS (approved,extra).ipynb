# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
link1 = "Datasets/student-mat.csv"
link2 = "Datasets/student-por.csv"

# %%
time.strftime('Fecha de ejecutación: %d-%m-%y hora: %I:%M:%S')
# Out:
# 'Fecha de ejecutación: 13-01-23 hora: 06:31:07'

# %%
school1 = pd.read_csv(link1, sep=';', usecols=['school', 'sex', 'age', 'address', 'Pstatus', 'guardian', 'traveltime', 'studytime', 'failures', 'paid', 'internet', 'health', 'absences', 'G1', 'G2', 'G3'])
school1.tail()
# Out:
#     school sex  age address Pstatus guardian  traveltime  studytime  failures  \
# 390     MS   M   20       U       A    other           1          2         2
# 391     MS   M   17       U       T   mother           2          1         0
# 392     MS   M   21       R       T    other           1          1         3
# 393     MS   M   18       R       T   mother           3          1         0
# 394     MS   M   19       U       T   father           1          1         0
#
#     paid internet  health  absences  G1  G2  G3
# 390  yes       no       4        11   9   9   9
# 391   no      yes       2         3  14  16  16
# 392   no       no       3         3  10   8   7
# 393   no      yes       5         0  11  12  10
# 394   no      yes       5         5   8   9   9

# %%
school2 = pd.read_csv(link2, sep=';', usecols=['school', 'sex', 'age', 'address', 'Pstatus', 'guardian', 'traveltime', 'studytime', 'failures', 'paid', 'internet', 'health', 'absences', 'G1', 'G2', 'G3'])
school2.tail()
# Out:
#     school sex  age address Pstatus guardian  traveltime  studytime  failures  \
# 644     MS   F   19       R       T   mother           1          3         1
# 645     MS   F   18       U       T   mother           1          2         0
# 646     MS   F   18       U       T   mother           2          2         0
# 647     MS   M   17       U       T   mother           2          1         0
# 648     MS   M   18       R       T   mother           3          1         0
#
#     paid internet  health  absences  G1  G2  G3
# 644   no      yes       5         4  10  11  10
# 645   no      yes       1         4  15  15  16
# 646   no       no       5         6  11  12   9
# 647   no      yes       2         6  10  10  10
# 648   no      yes       5         4  10  11  11

# %%
school1=school1[school1!='GP']
school1=school1[school1['school'].notna()]

# %%
school2=school2[school2!='GP']
school2=school2[school2['school'].notna()]

# %%
approved=[]
extra=[]
aux=[]

# %%
def puntaje1(valor):
        if  (93-valor*100/93<=80):
            return 0
        elif (93-valor*100/93 >80):
            return 1

# %%
def puntaje2(valor):
        if  (valor<10):
            return 0
        elif (10<=valor<15):
            return 1
        elif (valor>=15):
            return 1

# %%
def puntaje3(valor):
        if (10<=valor<=15):
            return 1
        elif (valor>=15):
            return 0
        elif (valor<10):
            return ""

# %%
for valor in school1["absences"]:
    approved.append(puntaje1(valor))

# %%
for valor in school1["G3"]:
    aux.append(puntaje2(valor))

# %%
for x in range (len(approved)):
    if(approved[x]!=aux[x]):
        approved[x]=aux[x]

# %%
for valor in school1["G3"]:
    extra.append(puntaje3(valor))

# %%
school1["approved"]=approved
school1["extra"]=extra

# %%
school1
# Out:
#     school sex  age address Pstatus guardian  traveltime  studytime  failures  \
# 349     MS   M   18       R       T   mother           2          1         1
# 350     MS   M   19       R       T    other           3          2         3
# 351     MS   M   17       U       T   mother           2          2         0
# 352     MS   M   18       U       T   mother           1          1         1
# 353     MS   M   19       R       T    other           3          1         1
# 354     MS   M   17       R       T   mother           2          2         0
# 355     MS   F   18       U       T   father           1          2         0
# 356     MS   F   17       R       T   father           2          2         0
# 357     MS   F   17       U       A   mother           2          2         0
# 358     MS   M   18       U       T   father           2          1         0
# 359     MS   F   18       U       T   father           2          3         0
# ...

# %%
approved1=[]
extra1=[]
aux1=[]

# %%
def puntaje4(valor):
        if  (93-valor*100/93<=80):
            return 0
        elif (93-valor*100/93 >80):
            return 1

# %%
def puntaje5(valor):
        if  (valor<10):
            return 0
        elif (10<=valor<15):
            return 1
        elif (valor>=15):
            return 1

# %%
def puntaje6(valor):
        if (10<=valor<=15):
            return 1
        elif (valor>=15):
            return 0
        elif (valor<10):
            return ""

# %%
for valor in school2["absences"]:
    approved1.append(puntaje4(valor))

# %%
for valor in school2["G3"]:
    aux1.append(puntaje5(valor))

# %%
for x in range (len(approved1)):
    if(approved1[x]!=aux1[x]):
        approved1[x]=aux1[x]

# %%
for valor in school2["G3"]:
    extra1.append(puntaje6(valor))

# %%
school2["approved"]=approved1
school2["extra"]=extra1

# %%
school2
# Out:
#     school sex  age address Pstatus guardian  traveltime  studytime  failures  \
# 423     MS   F   16       U       T   father           2          1         0
# 424     MS   F   16       R       T   mother           2          2         0
# 425     MS   F   15       R       T   mother           1          1         1
# 426     MS   F   15       R       T   mother           2          1         0
# 427     MS   F   16       R       T   mother           2          2         0
# ..     ...  ..  ...     ...     ...      ...         ...        ...       ...
# 644     MS   F   19       R       T   mother           1          3         1
# 645     MS   F   18       U       T   mother           1          2         0
# 646     MS   F   18       U       T   mother           2          2         0
# 647     MS   M   17       U       T   mother           2          1         0
# 648     MS   M   18       R       T   mother           3          1         0
#
# ...

# %%
school1.to_csv('D:/Proyecto_CP_Josue_Vasquez/Proyecto_Python_Escuela_MS_mat 12-01-2023.csv',sep=';')

# %%
school2.to_csv('D:/Proyecto_CP_Josue_Vasquez/Proyecto_Python_Escuela_MS_Port 12-01-2023.csv',sep=';')
